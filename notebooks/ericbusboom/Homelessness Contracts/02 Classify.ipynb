# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 
import spacy 
from spacy.tokens import DocBin

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
# !pip install -q -r ../requirements.txt

# %%
import metapack as mp
pkg = mp.open_package('http://library.metatab.org/sdcta.org-hl_contracts-1.1.1.zip')

# Create Dataframes
ann = pkg.resource('annotations').dataframe()
ann['length'] = ann.text.str.len()
ctx = pkg.resource('contexts').dataframe().set_index('part')

# %%
ann.head().T
# Out:
#                                                                  0  \
# classid                                                        e_7
# part                                                          s1v1
# offset_start                                                    33
# text                                           COUNTY OF SAN DIEGO
# coordinates                                                     []
# confidence                                                     NaN
# confidence_prob                                           0.975784
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:nalaf
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                                    payor
# length                                                          19
#
#                                                                  1  \
# classid                                                       e_19
# part                                                          s1v1
# offset_start                                                    33
# text             COUNTY OF SAN DIEGO- DEPARTMENT OF PURCHASINGA...
# coordinates                                                    NaN
# confidence                                               pre-added
# confidence_prob                                                1.0
# fields                                                          {}
# normalizations                                                  {}
# who                                                     user:SDTEF
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                             116.17
# coordinates_0_y                                              42.35
# coordinates_1_x                                             405.62
# coordinates_1_y                                              59.19
# value                                                         <NA>
# anno_type                                                 contract
# length                                                          89
#
#                                                                  2  \
# classid                                                        e_1
# part                                                          s1v1
# offset_start                                                   127
# text                                    Interfaith Shelter Network
# coordinates                                                     []
# confidence                                                     NaN
# confidence_prob                                           0.813213
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:nalaf
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                             organization
# length                                                          26
#
#                                                                  3  \
# classid                                                        e_6
# part                                                          s1v1
# offset_start                                                   153
# text                                                             .
# coordinates                                                     []
# confidence                                               pre-added
# confidence_prob                                                0.5
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:regex
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                             goal-service
# length                                                           1
#
#                                                                  4
# classid                                                        e_4
# part                                                          s1v1
# offset_start                                                   340
# text                                              Statement ofWork
# coordinates                                                     []
# confidence                                                     NaN
# confidence_prob                                           0.900681
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:nalaf
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                                  service
# length                                                          16

# %%
# Word tokenization

from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
from difflib import SequenceMatcher
import re


# Load English tokenizer, tagger, parser, NER and word vectors
nlp = English()

# Add the component to the pipeline
nlp.add_pipe('sentencizer')

def mark_sentences(idx,r, ctx):

    
    ctx_r = ctx.loc[r.part]

    text = re.sub(r"\n+","\n", ctx_r.context).lower()

    #  "nlp" Object is used to create documents with linguistic annotations.
    doc = nlp(text)

    spn = doc[r.offset_start: r.offset_start+r.length]

    # Create list of word tokens
    #token_list = [tok for tok in doc if tok.text not in STOP_WORDS]
    #print(token_list[:30])

    #print(spn)
    #print('++++')

    # Minimum size of block to match
    msize = int(len(spn)*.2)

    rows = []
    # Extract sentences and compute the overlap with the tagged text
    for s in doc.sents:

        sm = SequenceMatcher(None, spn.text, s.text)
        mb = [e for e in sm.get_matching_blocks() if e.size >= msize]

        anno_type = r.anno_type if len(mb) > 0 else None
       
        
        rows.append( (idx, r.part, s.text, anno_type) )
                        
    return rows

mark_sentences(4, ann.iloc[4], ctx)
# Out:
# [(4,
#   's1v1',
#   "sd cnty purch '15 :fp 14pm04:12\ncounty of san diego- department of purchasingand contracting contract 539655 amendment 10\nto interfaith shelter network.",
#   'service'),
#  (4,
#   's1v1',
#   'pursuant to the contract changes clause, you are directed to make the changes described herein to the contract or do the following described work not included in the previous agreed on statement ofwork.',
#   None),
#  (4,
#   's1v1',
#   '\ntitle of contract, temporary shelter network services\neffective date: 09/15115 description of contract change(s) and/or work to be done:\n• modify exhibit a and exhibit c to reflect the level of effort associated with fy 15-16 funding. •',
#   None),
#  (4,
#   's1v1',
#   'modify exhibit a to reflect a revision in language regarding health insurance.',
#   'service'),
#  (4,
#   's1v1',
#   '\nstatement of work:\n• add section 3.8 to read in its entirety as follows:\n3.8 bed nights: contractor shall provide a minimum of two thousand sixty nine (2068) nights of lodging countywide (outside san diego city limits) for the period of july i, 2015 through june 30, 2016.',
#   None),
#  (4,
#   's1v1',
#   '\n• add section 3.9 to read in its entirety as follows:\n3.9 transitional or permanent housing: for the period of july i, 2015 through june 30,2016, a minimum of forty (40) unduplicated homeless persons countywide shall obtain transitional or permanent housing.',
#   None),
#  (4,
#   's1v1',
#   '\n• add section 3.10 to read in its entirety as follows:\n3.10 jobs or other source oflncome: for the period ofjuly i, 2015 through june 30, 2016, a minimum of thirty (30) lodging guests shall obtain employment, other source of income (excluding county general relief and calfresh), increased employment hours and/or health benefits through employment on or before the day they exit a countywide service location.',
#   None),
#  (4, 's1v1', '\n• revise section 10.', 'service'),
#  (4,
#   's1v1',
#   'health insurance to read in its entirety as follows:\n10.',
#   'service'),
#  (4,
#   's1v1',
#   'health insurance\ncontractor shall ask any client if the client or any minor(s) for whom they are responsible have health insurance coverage.',
#   'service'),
#  (4,
#   's1v1',
#   'if the response is "no" for client or minor(s), the contractor shall refer the client to covered california at httos://www.coveredca.com/ or to call 1-800-300-1506.',
#   'service'),
#  (4,
#   's1v1',
#   '\nnote: exhibit a and exhibit c are attached for your reference.',
#   'service'),
#  (4, 's1v1', '\nall other terms and conditions remain in effect.', 'service'),
#  (4,
#   's1v1',
#   '\nin witness whereof, county and contractor have executed this amendment effective as of the date first set forth above.',
#   'service'),
#  (4,
#   's1v1',
#   'we, the undersigned contractor, have given careful\nthis amendment is not valid unless consideration to the change proposed and hereby agree, if this approved by the director, department of proposed change is approved, that we will provide all\npurchasingand contracting.',
#   None),
#  (4,
#   's1v1',
#   'equipment, furnish all materials, except as may otherwise be noted above, and perform all services necessary for the work specified herein, and will accept as full payment $25,000 for fiscal year 2015-2016.',
#   None),
#  (4, 's1v1', 'contract time for completion remains unchanged.', 'service'),
#  (4,
#   's1v1',
#   '\ncontract#\ndepartment review and recommended approval:\napproved:\ndate: 9-\\fs- \\6\namendment#',
#   'service')]

# %%
from itertools import chain
x = [mark_sentences(idx, row, ctx) for idx, row in ann.iterrows()]

# %%
df = pd.DataFrame( chain(*x), columns='idx part text anno_type'.split())

# %%
df.anno_type.value_counts(dropna=False)
# Out:
# years                93726
# payor                57560
# location             47978
# goal-service         47291
# service              33708
# NaN                  32376
# organization         29613
# compensation         28734
# target-population    11931
# contract              6278
# Name: anno_type, dtype: int64

# %%
# Another way to do test/train split
#from sklearn.model_selection import train_test_split
#train_df, test_df = train_test_split(df, test_size=0.2)
#tain_data = train_df[['text','cats']].values.tolist()
#test_data = test_df[['text','cats']].values.tolist()

# %%
from spacy.tokens import DocBin 

import en_core_web_lg
# load en_core_web_sm of English for vocabluary, syntax & entities
nlp = en_core_web_lg.load()

nlp.add_pipe('textcat', last=True)
textcat = nlp.get_pipe('textcat')

for at,_ in proto_d:
    textcat.add_label(at)

# %%
# If this fails, run :
# !python -m spacy download en_core_web_md
nlp = spacy.load('en_core_web_md')

# Create the categories data
proto_d = [ (e, 'F') for e in df.anno_type.unique() if e ]
def make_cat(cat):
    d = dict(proto_d)
    d[cat] = 'T'
    return d

df['cats'] = [make_cat(r.anno_type) for idx, r in df.iterrows() ]


def write_docs(df, path):
    
    docs = []
    for idx, row in df.iterrows():
   
        doc = nlp(row.text)
        doc.cats[str(row.anno_type)] = 1.0
        docs.append(doc)
        
    db = DocBin(docs=docs)
    db.to_disk(path)
    
write_docs(train_df.sample(500), 'train.spacy')
write_docs(test_df.sample(500), 'test.spacy')

# %%
# Check that save file makes sense
doc_bin = DocBin().from_disk('train.spacy')
docs = list(doc_bin.get_docs(nlp.vocab))
docs[0].cats
# Out:
# {'service': 1.0}

# %%
# Pre-training docs
from tqdm.notebook import tqdm
pt_docs = [nlp(row.text) for idx, row in tqdm(list(df.sample(5000).iterrows()))]
db = DocBin(docs=pt_docs)
db.to_disk('raw_text.spacy')
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
# Pretrain

# !python -m spacy pretrain config.cfg ./output
# Out:
# ⚠ Output directory is not empty.
# It is better to use an empty directory or refer to a new output path, then the
# new directory will be created for you.
# ℹ Using CPU
# ℹ Loading config from: config.cfg
# ✔ Saved config file in the output directory
#
# ============== Pre-training tok2vec layer - starting at epoch 0 ==============
#   #      # Words   Total Loss     Loss    w/s
# /Users/eric/opt/anaconda3/envs/text_class/lib/python3.9/site-packages/spacy/training/corpus.py:77: UserWarning: [W090] Could not locate any .jsonl files in path ''raw_text.spacy''.
#   warnings.warn(Warnings.W090.format(path=orig_path, format=file_type))
# ✔ Successfully finished pretrain

# %%
# Train
# !python -m spacy train config.cfg --output ./output
# Out:
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# [2021-08-17 17:39:09,050] [INFO] Set up nlp object from config
# [2021-08-17 17:39:09,059] [INFO] Pipeline: ['tok2vec', 'textcat']
# [2021-08-17 17:39:09,063] [INFO] Created vocabulary
# [2021-08-17 17:39:11,237] [INFO] Added vectors: en_core_web_lg
# [2021-08-17 17:39:13,486] [INFO] Finished initializing nlp object
# [2021-08-17 17:39:14,331] [INFO] Initialized pipeline components: ['tok2vec', 'textcat']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'textcat']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS TEXTCAT  CATS_SCORE  SCORE
# ---  ------  ------------  ------------  ----------  ------
#   0       0          0.00          0.02        0.00    0.00
#   1     200       1766.03         33.11        1.25    0.01
#   3     400        868.79         21.64        4.11    0.04
#   6     600       3676.73         17.39        4.32    0.04
#  10     800      97719.45          6.54        4.13    0.04
#  14    1000      66967.78          2.75        4.08    0.04
#  19    1200     352003.21          1.73        4.11    0.04
#  25    1400    1460501.83          0.91        4.54    0.05
#  33    1600    4831527.64          0.53        4.86    0.05
#  43    1800    7062329.01          0.32        2.28    0.02
#  55    2000   11392182.40          0.22        3.74    0.04
#  70    2200   69061406.39          0.15        4.38    0.04
#  87    2400   92509464.05          0.10        5.12    0.05
# 106    2600  272873746.62          0.08        2.18    0.02
# 124    2800  364647198.10          0.08        2.05    0.02
# 142    3000  579020870.09          0.08        4.44    0.04
# 160    3200  918672857.97          0.08        4.95    0.05
# 178    3400  1687078916.76          0.08        4.73    0.05
# 196    3600  2106016643.25          0.08        2.82    0.03
# 215    3800  2959256969.44          0.08        3.65    0.04
# 233    4000  4808147206.08          0.08        5.51    0.06
# 251    4200  5400618006.92          0.09        4.70    0.05
# 269    4400  6695214653.00          0.08        2.03    0.02
# 287    4600  11474057898.13          0.08        4.75    0.05
# 306    4800  12385002024.74          0.08        3.23    0.03
# 324    5000  18165572176.16          0.08        4.46    0.04
# 342    5200  24433867955.93          0.09        4.46    0.04
# 360    5400  28178718546.28          0.09        2.21    0.02
