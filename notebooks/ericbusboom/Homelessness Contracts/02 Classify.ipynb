# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
# !pip install -q -r ../requirements.txt

# %%
import metapack as mp
pkg = mp.open_package('http://library.metatab.org/sdcta.org-hl_contracts-1.1.1.zip')

# Create Dataframes
ann = pkg.resource('annotations').dataframe()
ann['length'] = ann.text.str.len()
ctx = pkg.resource('contexts').dataframe().set_index('part')

# %%
ann.head().T
# Out:
#                                                                  0  \
# classid                                                        e_7
# part                                                          s1v1
# offset_start                                                    33
# text                                           COUNTY OF SAN DIEGO
# coordinates                                                     []
# confidence                                                     NaN
# confidence_prob                                           0.975784
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:nalaf
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                                    payor
# length                                                          19
#
#                                                                  1  \
# classid                                                       e_19
# part                                                          s1v1
# offset_start                                                    33
# text             COUNTY OF SAN DIEGO- DEPARTMENT OF PURCHASINGA...
# coordinates                                                    NaN
# confidence                                               pre-added
# confidence_prob                                                1.0
# fields                                                          {}
# normalizations                                                  {}
# who                                                     user:SDTEF
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                             116.17
# coordinates_0_y                                              42.35
# coordinates_1_x                                             405.62
# coordinates_1_y                                              59.19
# value                                                         <NA>
# anno_type                                                 contract
# length                                                          89
#
#                                                                  2  \
# classid                                                        e_1
# part                                                          s1v1
# offset_start                                                   127
# text                                    Interfaith Shelter Network
# coordinates                                                     []
# confidence                                                     NaN
# confidence_prob                                           0.813213
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:nalaf
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                             organization
# length                                                          26
#
#                                                                  3  \
# classid                                                        e_6
# part                                                          s1v1
# offset_start                                                   153
# text                                                             .
# coordinates                                                     []
# confidence                                               pre-added
# confidence_prob                                                0.5
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:regex
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                             goal-service
# length                                                           1
#
#                                                                  4
# classid                                                        e_4
# part                                                          s1v1
# offset_start                                                   340
# text                                              Statement ofWork
# coordinates                                                     []
# confidence                                                     NaN
# confidence_prob                                           0.900681
# fields                                                          {}
# normalizations                                                  {}
# who                                                       ml:nalaf
# file_name        homelessness-contracts/ann.json/master/pool/ai...
# html_file_name   homelessness-contracts/plain.html/pool/aiViB0O...
# coordinates_0_x                                                NaN
# coordinates_0_y                                                NaN
# coordinates_1_x                                                NaN
# coordinates_1_y                                                NaN
# value                                                         <NA>
# anno_type                                                  service
# length                                                          16

# %%
# Word tokenization

from spacy.lang.en import English
from spacy.lang.en.stop_words import STOP_WORDS
from difflib import SequenceMatcher
import re


# Load English tokenizer, tagger, parser, NER and word vectors
nlp = English()

# Add the component to the pipeline
nlp.add_pipe('sentencizer')

def mark_sentences(idx,r, ctx):

    
    ctx_r = ctx.loc[r.part]

    text = re.sub(r"\n+","\n", ctx_r.context).lower()

    #  "nlp" Object is used to create documents with linguistic annotations.
    doc = nlp(text)

    spn = doc[r.offset_start: r.offset_start+r.length]

    # Create list of word tokens
    #token_list = [tok for tok in doc if tok.text not in STOP_WORDS]
    #print(token_list[:30])

    #print(spn)
    #print('++++')

    # Minimum size of block to match
    msize = int(len(spn)*.2)

    rows = []
    # Extract sentences and compute the overlap with the tagged text
    for s in doc.sents:

        sm = SequenceMatcher(None, spn.text, s.text)
        mb = [e for e in sm.get_matching_blocks() if e.size >= msize]

        anno_type = r.anno_type if len(mb) > 0 else None
       
        
        rows.append( (idx, r.part, s.text, anno_type) )
                        
    return rows

mark_sentences(4, ann.iloc[4], ctx)
# Out:
# [(4,
#   's1v1',
#   "sd cnty purch '15 :fp 14pm04:12\ncounty of san diego- department of purchasingand contracting contract 539655 amendment 10\nto interfaith shelter network.",
#   'service'),
#  (4,
#   's1v1',
#   'pursuant to the contract changes clause, you are directed to make the changes described herein to the contract or do the following described work not included in the previous agreed on statement ofwork.',
#   None),
#  (4,
#   's1v1',
#   '\ntitle of contract, temporary shelter network services\neffective date: 09/15115 description of contract change(s) and/or work to be done:\n• modify exhibit a and exhibit c to reflect the level of effort associated with fy 15-16 funding. •',
#   None),
#  (4,
#   's1v1',
#   'modify exhibit a to reflect a revision in language regarding health insurance.',
#   'service'),
#  (4,
#   's1v1',
#   '\nstatement of work:\n• add section 3.8 to read in its entirety as follows:\n3.8 bed nights: contractor shall provide a minimum of two thousand sixty nine (2068) nights of lodging countywide (outside san diego city limits) for the period of july i, 2015 through june 30, 2016.',
#   None),
#  (4,
#   's1v1',
#   '\n• add section 3.9 to read in its entirety as follows:\n3.9 transitional or permanent housing: for the period of july i, 2015 through june 30,2016, a minimum of forty (40) unduplicated homeless persons countywide shall obtain transitional or permanent housing.',
#   None),
#  (4,
#   's1v1',
#   '\n• add section 3.10 to read in its entirety as follows:\n3.10 jobs or other source oflncome: for the period ofjuly i, 2015 through june 30, 2016, a minimum of thirty (30) lodging guests shall obtain employment, other source of income (excluding county general relief and calfresh), increased employment hours and/or health benefits through employment on or before the day they exit a countywide service location.',
#   None),
#  (4, 's1v1', '\n• revise section 10.', 'service'),
#  (4,
#   's1v1',
#   'health insurance to read in its entirety as follows:\n10.',
#   'service'),
#  (4,
#   's1v1',
#   'health insurance\ncontractor shall ask any client if the client or any minor(s) for whom they are responsible have health insurance coverage.',
#   'service'),
#  (4,
#   's1v1',
#   'if the response is "no" for client or minor(s), the contractor shall refer the client to covered california at httos://www.coveredca.com/ or to call 1-800-300-1506.',
#   'service'),
#  (4,
#   's1v1',
#   '\nnote: exhibit a and exhibit c are attached for your reference.',
#   'service'),
#  (4, 's1v1', '\nall other terms and conditions remain in effect.', 'service'),
#  (4,
#   's1v1',
#   '\nin witness whereof, county and contractor have executed this amendment effective as of the date first set forth above.',
#   'service'),
#  (4,
#   's1v1',
#   'we, the undersigned contractor, have given careful\nthis amendment is not valid unless consideration to the change proposed and hereby agree, if this approved by the director, department of proposed change is approved, that we will provide all\npurchasingand contracting.',
#   None),
#  (4,
#   's1v1',
#   'equipment, furnish all materials, except as may otherwise be noted above, and perform all services necessary for the work specified herein, and will accept as full payment $25,000 for fiscal year 2015-2016.',
#   None),
#  (4, 's1v1', 'contract time for completion remains unchanged.', 'service'),
#  (4,
#   's1v1',
#   '\ncontract#\ndepartment review and recommended approval:\napproved:\ndate: 9-\\fs- \\6\namendment#',
#   'service')]

# %%
from itertools import chain
x = [mark_sentences(idx, row, ctx) for idx, row in ann.iterrows()]

# %%
df = pd.DataFrame( chain(*x), columns='idx part text anno_type'.split())

# %%
import en_core_web_lg
# load en_core_web_sm of English for vocabluary, syntax & entities
nlp = en_core_web_lg.load()

nlp.add_pipe('textcat', last=True)
textcat = nlp.get_pipe('textcat')

for at in ann.anno_type.unique():
    textcat.add_label(at)

nlp.pipe_names
# Out:
# ['tok2vec',
#  'tagger',
#  'parser',
#  'attribute_ruler',
#  'lemmatizer',
#  'ner',
#  'textcat']

# %%
def evaluate(tokenizer, textcat, texts, cats):
    docs = (tokenizer(text) for text in texts)
    tp = 1e-8  # True positives
    fp = 1e-8  # False positives
    fn = 1e-8  # False negatives
    tn = 1e-8  # True negatives
    for i, doc in enumerate(textcat.pipe(docs)):
        gold = cats[i]
        for label, score in doc.cats.items():
            if label not in gold:
                continue
            if score >= 0.5 and gold[label] >= 0.5:
                tp += 1.
            elif score >= 0.5 and gold[label] < 0.5:
                fp += 1.
            elif score < 0.5 and gold[label] < 0.5:
                tn += 1
            elif score < 0.5 and gold[label] >= 0.5:
                fn += 1
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f_score = 2 * (precision * recall) / (precision + recall)
    return {'textcat_p': precision, 'textcat_r': recall, 'textcat_f': f_score}

#("Number of texts to train from","t" , int)
n_texts=30000
#You can increase texts count if you have more computational power.

#("Number of training iterations", "n", int))
n_iter=10

# %%
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'textcat']
with nlp.disable_pipes(*other_pipes):  # only train textcat

# %%
# add label to text classifier
textcat.add_label('POSITIVE')
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc= nlp(text)
entities=[(i, i.label_, i.label) for i in doc.ents if i.label_ not in ('CARDINAL',) ]
entities
# Out:
# [(san diego, 'ORG', 383),
#  (a-79, 'ORG', 383),
#  ($14 million, 'MONEY', 394),
#  (san diego, 'GPE', 384),
#  (california, 'GPE', 384),
#  (california, 'GPE', 384),
#  (san diego, 'GPE', 384),
#  (3) year period, 'DATE', 391),
#  (3) year period, 'DATE', 391),
#  (five business days, 'DATE', 391),
#  (irs, 'ORG', 383)]

# %%
import spacy
spacy.displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">county of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     san diego
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  department of purchasing and contracting</br>representations and certifications</br>the following repr ntations and certifications are to be completed, signed and returned with the offer.</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . business typ</br>0 for-profit on-profit 0 government attach proof o status for non-profit.</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . interlocking directorate</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .</br>in accordance with board of supervisors policy
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a-79
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , if offeror is a non-profit as indicated in paragraph
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  above, offeror is required to identify any related for-profit subcontractors in which an interlocking directorate, management or ownership relationship exists. by submission of this offer, offeror certifies it will not enter into a subcontract relationship with a related for-profit entity if offeror is a non-profit entity. if offeror is a non-profrt and will be subcontracting with a related for-profit entity, offeror must list the entity(ies) on an attached separate sheet listing them all and the oontract must be approved by the board of supervisors</br>business representation offeror represents as a part of this offer that the ownership, operation, and control of the business are:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3.4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .</br>are you a small business with:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  or fewer employees and erage annual gross receipts of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $14 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  or less o a manufacturer with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     100
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  or fev.er employees?</br>yes 0 no are you a local business wit&quot;;;' ~ysical address within the county of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     san diego
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ? b-1~s 0 no are you certified by the state of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     california
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as a:</br>0 disabled veteran business enterprise (dvbe) certification #:</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  small business enterprise (sbe) certification #:</br>see the state of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     california
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , department of general services v.ebsite for details on &quot;certified small business&quot; and &quot;certified dvbe&quot; requirements.</br>hl~;;_:f/yvij:tyj'. do~s.£::~.~-l9y.:£~;_tc:~~~gf ilm::;:tp30§._-a_s_.p_$.. estimated percentage of v..ork in this offer to be performed or fulfilled locally (within the geogr~h~</br>boundaries of the county of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     san diego
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ): ..
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em;

# %%
ents = []
for idx, row in ctx.iterrows():
    text = row.context
    doc = nlp(text.lower())
    entities=[(i, i.label_, i.label) for i in doc.ents if i.label_ not in ('CARDINAL',) ]
    ents.extend(entities)

# %%
t = set([ e[0:2] for e in ents])
set(label  for tok, label in t)
# Out:
# {'DATE',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART'}

# %%
set([tok.text  for tok, label in t if label == 'NORP'])
# Out:
# {'african american',
#  'american',
#  'americans',
#  'catholic',
#  'd.',
#  'hawaiian',
#  'hispanic',
#  'hispanics',
#  'lgbtq',
#  'non-hispanic',
#  'spanish'}

# %%
set([tok.text  for tok, label in t if label == 'GPE'])
# Out:
# {'2950 el cajon bl~',
#  '6,600.00',
#  '\\)\\',
#  'ab',
#  'accountina',
#  'angeles',
#  'angeles county',
#  'ave',
#  'ave los angeles',
#  'ave.',
#  'beverly hills',
#  'budget2014-15',
#  'california',
#  'california landlord!tenant',
#  'camino del rio south address',
#  'carlsbad',
#  'culver city',
#  'delaware',
#  'diego',
#  'east county',
#  'el cajon',
#  'el cajon blvd',
#  'el cajon city',
#  "el cajon's",
#  'escondido',
#  'fremont',
#  'fresno',
#  'fresno county',
#  'ga',
#  'http://www.sdcounty.ca.gov/hhsa/programs/phs/tuberculosis_control_program/guidelines_additional_resources.html',
#  'los angeles',
#  'los angeles county',
#  'm.d.',
#  'marengo st',
#  'marengo st\n\n',
#  'maryland',
#  'md',
#  'n.a.',
#  'north county',
#  'north county lifeline',
#  'oceanside',
#  'oflos angeles',
#  'p.l.',
#  'p.o.',
#  'pennsylvania',
#  'philadelphia',
#  'portland',
#  'poway',
#  'redondo beach',
#  'san',
#  'san dibqo',
#  'san diego',
#  'san diego -health',
#  'san diego city',
#  'san diego county',
#  'san diego county\n\n',
#  "san diego's",
#  'san francisco',
#  'san marcos',
#  'sbc',
#  'se!vice',
#  'serv1ce',
#  'shm1-',
#  'shreddina',
#  'st los',
#  'st los angeles',
#  'ste',
#  'the united kingdom',
#  'the united states',
#  'u.s.',
#  'virginia',
#  'virginia west',
#  'west f!frh',
#  'wilmington'}
